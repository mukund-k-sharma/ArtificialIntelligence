# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
salary_data = pd.read_csv('./data/Salary_year.csv')
salary_data.head(2)
# Out:
#    YearsExperience  Salary
# 0              1.0   32383
# 1              1.1   45207

# %%
X = salary_data.iloc[:, :-1].values
y = salary_data.iloc[:, 1].values

# %%
# Splitting data between training and test set.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %%
# Fitting data using Simple Linear Regression model
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# R-square value
r_sq = model.score(X_train, y_train)
print(f'Coefficient of determination : {r_sq}')
# Out:
# Coefficient of determination : 0.896323114885137

# %%
print(f'Model coefficient: {model.coef_}')
# Out:
# Model coefficient: [5994.3184079]

# %%
print(f'Intercept : {model.intercept_}')
# Out:
# Intercept : 34636.727413178916

# %%
# Prediction on training and test data
y_test_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)

print(y_test_pred)

print(y_train_pred)
# Out:
# [42429.34134346 85588.43388037 59213.43288559 58014.56920401
#  82591.27467642 78395.25179088 83790.138358   58614.0010448
#  65807.18313428 75398.09258693]
# [50821.38711452 64608.3194527  53818.54631847 61611.16024875
#  76596.95626851 71801.50154219 41230.47766187 87386.72940274
#  52619.68263689 47824.22791057 68204.91049745 70602.63786061
#  56815.70552243 53818.54631847 80193.54731326 46625.36422899
#  40631.04582108 73599.79706456 63409.45577112 58614.0010448 ]

# %%
# Visualizing Training data
plt.scatter(X_train, y_train, color='blue')
plt.plot(X_train, y_train_pred, color='red')
plt.title("Salary vs Experience (Training Dataset)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary (In Rupees)")
plt.show()

# %%
# Visualizing Test data
plt.scatter(X_test, y_test, color='green')
plt.plot(X_test, y_test_pred, color='red')
plt.title("Salary vs Experience (Training Dataset)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary (In Rupees)")
plt.show()
